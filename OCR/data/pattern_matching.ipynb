# %%
# pattern matching
import cv2
import pytesseract

# %%
img=cv2.imread('/home/sajmi/Desktop/BD_MAY/OCR/data/invoice.jpeg')

# %%
cv2.imshow('invoice',img)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
from pytesseract import Output

# %%
data=pytesseract.image_to_data(img,output_type=Output.DICT)

# %%
data.keys()
# Out:
# dict_keys(['level', 'page_num', 'block_num', 'par_num', 'line_num', 'word_num', 'left', 'top', 'width', 'height', 'conf', 'text'])

# %%
data['text']
# Out:
# ['',
#  '',
#  '',
#  '',
#  ',',
#  'Invoice',
#  '',
#  '',
#  '',
#  'Your',
#  'Company',
#  'LLC',
#  'Address',
#  '123,',
#  'State,',
#  'My',
#  'Country',
#  'P',
#  '111-222-333,',
#  'F',
#  '111-222-334',
#  '',
#  '',
#  '',
#  'BILL',
#  'TO:',
#  '',
#  'John',
#  'Doe',
#  '',
#  '',
#  'Alpha',
#  'Bravo',
#  'Road',
#  '33',
#  '',
#  '',
#  'P:',
#  '111-222-338,',
#  'F:',
#  '111-222-334',
#  '',
#  'client@example.net',
#  '',
#  '',
#  '',
#  'SHIPPING',
#  'TO:',
#  '',
#  'John',
#  'Doe',
#  'Office',
#  '',
#  '',
#  'Office',
#  'Road',
#  '38,',
#  '',
#  '',
#  'P:',
#  '111-383-222,',
#  'F:',
#  '122-222-834',
#  '',
#  'office@example.net',
#  '',
#  '',
#  '',
#  'http://mrsinvoice.com',
#  '',
#  '',
#  '',
#  ' ',
#  '',
#  '',
#  '',
#  ' ',
#  '',
#  '',
#  '',
#  ' ',
#  '',
#  '',
#  '',
#  ' ',
#  '',
#  '',
#  '',
#  ' ',
#  '',
#  '',
#  '',
#  'Invoice',
#  '#',
#  '00001',
#  '',
#  'Invoice',
#  'Date',
#  '12/12/2001',
#  '',
# ...

# %%
data['conf']
# Out:
# [-1,
#  -1,
#  -1,
#  -1,
#  0,
#  95,
#  -1,
#  -1,
#  -1,
#  92,
#  96,
#  94,
#  89,
#  89,
#  96,
#  96,
#  93,
#  93,
#  90,
#  70,
#  70,
#  -1,
#  -1,
#  -1,
#  27,
#  27,
#  -1,
#  96,
#  93,
#  -1,
#  -1,
#  59,
#  96,
#  94,
#  95,
#  -1,
#  -1,
#  72,
#  72,
#  91,
#  76,
#  -1,
#  89,
#  -1,
#  -1,
#  -1,
#  88,
#  95,
#  -1,
#  96,
#  92,
#  93,
#  -1,
#  -1,
#  96,
#  95,
#  72,
#  -1,
#  -1,
#  67,
#  67,
#  88,
#  72,
#  -1,
#  63,
#  -1,
#  -1,
#  -1,
#  76,
#  -1,
#  -1,
#  -1,
#  95,
#  -1,
#  -1,
#  -1,
#  95,
#  -1,
#  -1,
#  -1,
#  95,
#  -1,
#  -1,
#  -1,
#  95,
#  -1,
#  -1,
#  -1,
#  95,
#  -1,
#  -1,
#  -1,
#  92,
#  92,
#  86,
#  -1,
#  96,
#  87,
#  87,
#  -1,
#  95,
#  96,
#  96,
#  96,
#  -1,
#  -1,
#  95,
#  96,
#  56,
#  -1,
#  -1,
#  -1,
#  95,
#  -1,
#  -1,
#  -1,
#  96,
#  96,
#  -1,
#  -1,
#  -1,
#  95,
#  -1,
#  -1,
#  -1,
#  95,
#  -1,
#  -1,
#  -1,
#  94,
#  93,
#  93,
#  -1,
#  -1,
#  -1,
#  95,
#  -1,
#  -1,
#  -1,
#  95,
#  -1,
#  -1,
#  -1,
# ...

# %%
n_boxes=len(data['text'])
n_boxes
# Out:
# 234

# %%
for i in range(n_boxes):
        if data['conf'][i]>=70:
            x,y,w,h=data['left'][i],data['top'][i],data['width'][i],data['height'][i]
            cv2.rectangle(img,(x,y),(x+w,y+h),(100,255,0),3)
cv2.imshow('text',img)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
import re

# %%
# We need only date and email only,here date and email pattern dowmloaded from google(stack overflow)

img=cv2.imread('/home/sajmi/Desktop/BD_MAY/OCR/data/invoice.jpeg')
date_pattern='^(0?[1-9]|[12][0-9]|3[01])[\/\-](0?[1-9]|1[012])[\/\-]\d{4}$'
email_pattern='^[a-z0-9](\.?[a-z0-9]){5,}@example\.net$'
for i in range(n_boxes):
    if data['conf'][i]>=70:     
        if re.match(date_pattern,data['text'][i]):   # matching date
            x,y,w,h=data['left'][i],data['top'][i],data['width'][i],data['height'][i]
            cv2.rectangle(img,(x,y),(x+w,y+h),(100,255,0),3)
cv2.imshow('text1',img)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
# matching email

img=cv2.imread('/home/sajmi/Desktop/BD_MAY/OCR/data/invoice.jpeg')

for i in range(n_boxes):

    if data['conf'][i]>=70:
        
        if re.match(email_pattern,data['text'][i]):
            x,y,w,h=data['left'][i],data['top'][i],data['width'][i],data['height'][i]
            cv2.rectangle(img,(x,y),(x+w,y+h),(100,255,0),3)
cv2.imshow('email',img)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
# date and mail together

img=cv2.imread('/home/sajmi/Desktop/BD_MAY/OCR/data/invoice.jpeg')

for i in range(n_boxes):

    if data['conf'][i]>=70:

        if re.match(email_pattern,data['text'][i]) or re.match(date_pattern,data['text'][i]):
            
            x,y,w,h=data['left'][i],data['top'][i],data['width'][i],data['height'][i]
            cv2.rectangle(img,(x,y),(x+w,y+h),(100,255,0),3)
cv2.imshow('emaildate',img)
cv2.waitKey()
cv2.destroyAllWindows()
